# %% [markdown]
# <a href="https://colab.research.google.com/github/wasilone11/Data-Science-20-Feb-Optimizing-Lending-Club-s-Financial-Risk/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Author : Abdul Wasi

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/gdrive/My Drive/kaggle'

# %%
# %cd /content/gdrive/My Drive/kaggle
# Out:
# /content/gdrive/My Drive/kaggle

# %%
# !kaggle datasets download -d wordsforthewise/lending-club
# Out:
# ...
# 100% 1.26G/1.26G [00:18<00:00, 63.0MB/s]
# 100% 1.26G/1.26G [00:18<00:00, 73.5MB/s]

# %%
# !unzip \*.zip && rm*.zip
# Out:
# Archive:  lending-club.zip
#   inflating: accepted_2007_to_2018Q4.csv.gz
#   inflating: accepted_2007_to_2018q4.csv/accepted_2007_to_2018Q4.csv
#   inflating: rejected_2007_to_2018Q4.csv.gz
#   inflating: rejected_2007_to_2018q4.csv/rejected_2007_to_2018Q4.csv
# /bin/bash: rm*.zip: command not found

# %%
df = pd.read_csv("/content/gdrive/My Drive/kaggle/accepted_2007_to_2018Q4.csv.gz")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          id  member_id  ...  settlement_percentage  settlement_term
# 0  68407277        NaN  ...                    NaN              NaN
# 1  68355089        NaN  ...                    NaN              NaN
# 2  68341763        NaN  ...                    NaN              NaN
# 3  66310712        NaN  ...                    NaN              NaN
# 4  68476807        NaN  ...                    NaN              NaN
#
# [5 rows x 151 columns]

# %%
missing_values_count = df.isnull().sum()
missing_values_count[0:20]
# Out:
# id                           0
# member_id              2260701
# loan_amnt                   33
# funded_amnt                 33
# funded_amnt_inv             33
# term                        33
# int_rate                    33
# installment                 33
# grade                       33
# sub_grade                   33
# emp_title               167002
# emp_length              146940
# home_ownership              33
# annual_inc                  37
# verification_status         33
# issue_d                     33
# loan_status                 33
# pymnt_plan                  33
# url                         33
# desc                   2134634
# dtype: int64

# %%
df = df.drop(['title', 'url', 'zip_code', 'addr_state'], axis=1)

# %%
max_number_of_nas = 1000000
df = df.loc[:, (df.isnull().sum(axis=0) < max_number_of_nas)]
#helped us to remove columns with around half entries as NA

# %%
df.shape
df.head()
# Out:
#          id  loan_amnt  ...  disbursement_method  debt_settlement_flag
# 0  68407277     3600.0  ...                 Cash                     N
# 1  68355089    24700.0  ...                 Cash                     N
# 2  68341763    20000.0  ...                 Cash                     N
# 3  66310712    35000.0  ...                 Cash                     N
# 4  68476807    10400.0  ...                 Cash                     N
#
# [5 rows x 102 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(1, 3, figsize=(12,4))

loan_amnt = df["loan_amnt"].values
funded_amnt = df["funded_amnt"].values
funded_amnt_inv = df["funded_amnt_inv"].values


sns.distplot(loan_amnt, ax=ax[0], color="blue")
ax[0].set_title("Loan Applied by the Borrower", fontsize=12)
sns.distplot(funded_amnt, ax=ax[1], color="red")
ax[1].set_title("Amount Funded by the Lender", fontsize=12)
sns.distplot(funded_amnt_inv, ax=ax[2], color="green")
ax[2].set_title("Total committed by Investors", fontsize=12)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df['issue_d'].head()
dt_series = pd.to_datetime(df['issue_d'])
df['year_wise'] = dt_series.dt.year
sns.lineplot(x="year_wise" , y="funded_amnt", data = df)

# %%
df['grade'] = df['grade'].astype('category')
df['grade'].value_counts()
# Out:
# B    663557
# C    650053
# A    433027
# D    324424
# E    135639
# F     41800
# G     12168
# Name: grade, dtype: int64

# %%
sns.scatterplot(x="grade", y="int_rate", data=df, palette="Blues_d")
#plt.show()

# %%
df['loan_status'] = df['loan_status'].astype('category')
df['loan_status'].value_counts()
#Most of the loans have been fully paid
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %%
plt.figure(figsize=(14, 6))
sns.barplot(x="sub_grade", y="int_rate", data=df)
plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x="purpose", y="loan_amnt", data=df)
plt.xticks(rotation=40) 
plt.show()
